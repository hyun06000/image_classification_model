# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

import tensorflow_datasets as tfds

from data.imagenet_labels import imagenet_labels

# %%
#tfds.list_builders() #'imagenet2012'
ds_name = 'imagenet2012'
builder = tfds.builder(ds_name)

# %%
builder.download_and_prepare()

'''
Downloading and preparing dataset Unknown size
(download: Unknown size, generated: 155.84 GiB, total: 155.84 GiB) to 
/root/tensorflow_datasets/imagenet2012/5.1.0...
Dataset imagenet2012 downloaded and prepared to 
/root/tensorflow_datasets/imagenet2012/5.1.0. 
Subsequent calls will reuse this data.
'''
# Out:
# '\nDownloading and preparing dataset Unknown size\n(download: Unknown size, generated: 155.84 GiB, total: 155.84 GiB) to \n/root/tensorflow_datasets/imagenet2012/5.1.0...\nDataset imagenet2012 downloaded and prepared to \n/root/tensorflow_datasets/imagenet2012/5.1.0. \nSubsequent calls will reuse this data.\n'

# %%
tr_ds, te_ds, val_ds = builder.as_dataset(split = ['train', 'test','validation'], shuffle_files = True)
print(tr_ds)
print(te_ds)
print(val_ds)
# Out:
# <_OptionsDataset shapes: {file_name: (), image: (None, None, 3), label: ()}, types: {file_name: tf.string, image: tf.uint8, label: tf.int64}>
# <_OptionsDataset shapes: {file_name: (), image: (None, None, 3), label: ()}, types: {file_name: tf.string, image: tf.uint8, label: tf.int64}>
# <_OptionsDataset shapes: {file_name: (), image: (None, None, 3), label: ()}, types: {file_name: tf.string, image: tf.uint8, label: tf.int64}>

# %%
'''
indx, max_v, max_h = 0, 0, 0
for example in tr_ds:
    indx += 1
    im = example['image']
    max_v = max(max_v, im.shape[0])
    max_h = max(max_h, im.shape[1])

print('the_number_of_data : ', indx)
print('the_max_v_size : ', max_v)
print('the_max_h_size : ', max_h)

'''

tr_ds = tr_ds.take(1)
for example in tr_ds:
    print(list(example.keys()))
    file_name = example['file_name']
    image = example['image']
    label = example['label']
    
    print('file_name : ',file_name)
    print(image.shape)
    plt.imshow(image)
    plt.show()
    print('label : ',imagenet_labels[label.numpy()])
# Out:
# ['file_name', 'image', 'label']
# file_name :  tf.Tensor(b'n02835271_24241.JPEG', shape=(), dtype=string)
# (300, 350, 3)
# label :  bicycle-built-for-two, tandem bicycle, tandem

# %%
type(image.numpy()[0][0][0])
#type(label.numpy())
# Out:
# numpy.uint8

# %%
indx, max_v, max_h = 0, 0, 0
for example in val_ds:
    indx += 1
    im = example['image']
    max_v = max(max_v, im.shape[0])
    max_h = max(max_h, im.shape[1])

print('the_number_of_data : ', indx)
print('the_max_v_size : ', max_v)
print('the_max_h_size : ', max_h)


val_ds = val_ds.take(1)
for example in val_ds:
    print(list(example.keys()))
    file_name = example['file_name']
    image = example['image']
    label = example['label']
    
    print('file_name : ',file_name)
    plt.imshow(image)
    plt.show()
    print('label : ',imagenet_labels[label.numpy()])

# %%
te_ds = te_ds.take(1)

for example in te_ds:
    print(list(example.keys()))
    file_name = example['file_name']
    image = example['image']
    label = example['label']
    
    print('file_name : ',file_name)
    plt.imshow(image)
    plt.show()
    print('label : ',label)

# %%
16 * 1024
# Out:
# 16384

# %%
16 * 512
# Out:
# 8192
